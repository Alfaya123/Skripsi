# %%
{
  "intents": [
    {
      "tag": "greeting",
      "patterns": [
        "hallo",
        "hai",
        "halo",
        "hei",
        "hi",
        "hy",
        "pagi",
        "morning",
        "siang",
        "afternoon",
        "sore",
        "malam",
        "bro",
        "sis",
        "kawan"
      ],
      "responses": [
        "Hai! Skripsibot di sini. Mau tau informasi tentang apa nih?",
        "Halo! Saya Skripsibot, salam kenal ya! Mau tau tentang skripsi, kan?",
        "Helo! Ini Skripsibot. Kamu Mahasiswa semester akhir ya? Lagi kepo tentang skripsi ya?"
      ]
    },
    {
      "tag": "skripsibot",
      "patterns": [
        "Apa itu SkripsiBot?",
        "Siapa SkripsiBot?"
      ],
      "responses": [
        "SkripsiBot adalah aplikasi chatbot informasi tentang skripsi"
        "SkripsiBot itu adalah teman informasi kamu tentang skripsi!"
      ]
    },
    {
        "tag":"bab_1", 
        "patterns": [
            "Apa saja yang terdapat dalam Bab 1?"
            "Bab 1 berisi apa aja?"
        ],
        "responses": [
            "Bab 1 merupakan pendahuluan yang berisi latar belakang, rumusan masalah, tujuan penelitian, ruang lingkup dan manfaat penelitian"
        ]
    },
    {      
      "tag": "perbedaan_fenomena_gap_dan_research_gap",
      "patterns": [
        "Apa perbedaan fenomena gap dengan research gap?",
        "Apasih fenomena gap dan research gap?"
      ],
      "responses": [
        "Research gap adalah kesenjangan hasil dalam penelitian yang ditunjukan dengan perbedaan hasil dari penelitian–penelitian sebelumnya yag telah dilakukan. Sedangkan, fenomena gap adalah kesenjangan yang terjadi di antara teori dan fakta yang ada"
      ]
      }
